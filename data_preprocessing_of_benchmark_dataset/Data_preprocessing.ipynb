# %%
import pandas as pd

# %%
data_test = pd.read_csv("./Benchmark_dataset/HeldOut50/Test_0_0.tsv",delimiter='\t',header=None)

# %%
data_test
# Out:
#            0       1  2
# 0       6810    9342  1
# 1       2074    4170  0
# 2     221656  730291  0
# 3      54623   79812  0
# 4        351    2242  1
# ...      ...     ... ..
# 6825  284013  286749  0
# 6826    5355    6657  0
# 6827     239    3632  0
# 6828    2074    8335  1
# 6829    2115   63971  0
#
# [6830 rows x 3 columns]

# %%
data_train = pd.read_csv("./Benchmark_dataset/HeldOut50/Train_0_0.tsv",delimiter='\t',header=None)

# %%
data_train
# Out:
#            0       1  2
# 0       8812  165140  1
# 1       5581   93953  0
# 2      56165  284293  0
# 3       1788   10919  1
# 4        999   54894  1
# ...      ...     ... ..
# 99995   3172   10987  1
# 99996  10107   58478  0
# 99997  27185   55180  0
# 99998   1674    6047  1
# 99999  23270   93979  0
#
# [100000 rows x 3 columns]

# %%
train_prot = set(data_train[0]).union(set((data_train[1])))

# %%
train_prot
# Out:
# {1,
#  2,
#  9,
#  10,
#  12,
#  13,
#  14,
#  15,
#  16,
#  18,
#  19,
#  20,
#  22,
#  23,
#  131096,
#  27,
#  28,
#  29,
#  31,
#  32,
#  33,
#  34,
#  35,
#  37,
#  38,
#  39,
#  40,
#  41,
#  43,
#  131118,
#  47,
#  48,
#  49,
#  50,
#  51,
#  52,
#  53,
#  54,
#  56,
#  58,
#  59,
#  70,
#  71,
#  72,
#  81,
#  86,
#  87,
#  88,
#  89,
#  90,
#  91,
#  92,
#  93,
#  94,
#  95,
#  98,
#  100,
#  101,
#  102,
#  105,
#  131177,
#  107,
#  108,
#  109,
#  111,
#  112,
#  113,
#  114,
#  116,
#  118,
#  119,
#  120,
#  123,
#  124,
#  125,
#  126,
#  127,
#  128,
#  132,
#  135,
#  136,
#  140,
#  141,
#  142,
#  143,
#  146,
#  147,
#  150,
#  151,
#  152,
#  153,
#  154,
#  155,
#  156,
#  157,
#  158,
#  159,
#  160,
#  161,
#  162,
#  163,
#  164,
#  165,
#  166,
#  167,
#  173,
#  175,
#  176,
#  178,
#  181,
#  182,
#  183,
#  185,
#  189,
#  190,
#  191,
#  196,
#  197,
#  199,
#  202,
#  203,
#  204,
#  205,
#  207,
#  208,
#  210,
#  211,
#  212,
#  213,
#  215,
#  216,
# ...

# %%
test_prot = set(data_test[0]).union(set((data_test[1])))

# %%
train_prot.intersection(test_prot)
# Out:
# set()
